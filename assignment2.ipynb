# %%
#why we cannot call local variable from outside functions
"""
the local variables cant be called because of its scopes there are 2 types of scopes local scope and global scope

# %%
#where do you use map, filter and reduce
"""
map : is used when u want to apply a function  to every item in a list(square of all numbers)
filter : when u want to keep only some elements based on condition(ex: even)
reduce : when u want to combine all elementsvinto one value(ex: add)

# %%
#calculator with exception
def calculator():
   while True:
       try:
           
           num1 = float(input("Enter the first number: "))
           num2 = float(input("Enter the second number: "))
           
           operator = input("Enter an operator (+, -, *, /): ")
           if operator == "+":
               result = num1 + num2
           elif operator == "-":
               result = num1 - num2
           elif operator == "*":
               result = num1 * num2
           elif operator == "/":
               try:
                   result = num1 / num2
               except ZeroDivisionError:
                   print("Error: Division by zero is not allowed.")
                   continue
           else:
               print("Invalid operator. Please try again.")
               continue
           print(f"The result is: {result}")
       except ValueError:
           print("Invalid input. Please enter numeric values.")
       choice = input("Do u want to continue (y/n): ").lower()
       if choice != 'y':
           print("Exiting the calculator. Goodbye!")
           break
calculator()
# Out:
# Enter the first number:  1
# Enter the second number:  2
# Enter an operator (+, -, *, /):  *
# The result is: 2.0
# Do u want to continue (y/n):  n
# Exiting the calculator. Goodbye!
